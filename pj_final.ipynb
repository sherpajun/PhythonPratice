# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import warnings
plt.rcParams['font.family']='Malgun Gothic'

# %%
warnings.filterwarnings(action='ignore')

# %%
a = pd.read_excel('./data/dust/2011/2011년01분기.xlsx')
b = pd.read_excel('./data/dust/2011/2011년02분기.xlsx')
c = pd.read_excel('./data/dust/2011/2011년03분기.xlsx')
d = pd.read_excel('./data/dust/2011/2011년04분기.xlsx')

# %%
a = a[a['지역'].str.contains('부산')]
b = b[b['지역'].str.contains('부산')]
c = c[c['지역'].str.contains('부산')]
d = d[d['지역'].str.contains('부산')]

# %%
df11 = pd.concat([a,b,c,d], ignore_index=True)
df11.to_csv('2011.csv',index=False)

# %%
aa = df11['SO2']==-999.000
dfa = df11[aa]
dfa.to_csv('999.csv')

# %%
a = pd.read_excel('./data/dust/2012/2012년01분기.xlsx')
b = pd.read_excel('./data/dust/2012/2012년02분기.xlsx')
c = pd.read_excel('./data/dust/2012/2012년03분기.xlsx')
d = pd.read_excel('./data/dust/2012/2012년04분기.xlsx')
a = a[a['지역'].str.contains('부산')]
b = b[b['지역'].str.contains('부산')]
c = c[c['지역'].str.contains('부산')]
d = d[d['지역'].str.contains('부산')]
df12 = pd.concat([a,b,c,d], ignore_index=True)
df12.to_csv('2012.csv',index=False)

# %%
a = pd.read_excel('./data/dust/2013/2013년01분기.xlsx')
b = pd.read_excel('./data/dust/2013/2013년02분기.xlsx')
c = pd.read_excel('./data/dust/2013/2013년03분기.xlsx')
d = pd.read_excel('./data/dust/2013/2013년04분기.xlsx')
a = a[a['지역'].str.contains('부산')]
b = b[b['지역'].str.contains('부산')]
c = c[c['지역'].str.contains('부산')]
d = d[d['지역'].str.contains('부산')]
df13 = pd.concat([a,b,c,d], ignore_index=True)
df13
# Out:
#            지역 측정소명   측정소코드        측정일시    SO2   CO     O3    NO2  PM10  \
# 0       부산 중구  광복동  221112  2013010101  0.005  0.5  0.024  0.026    41
# 1       부산 중구  광복동  221112  2013010102  0.005  0.5  0.022  0.026    33
# 2       부산 중구  광복동  221112  2013010103  0.005  0.4  0.029  0.019    34
# 3       부산 중구  광복동  221112  2013010104  0.005  0.4  0.032  0.016    33
# 4       부산 중구  광복동  221112  2013010105  0.005  0.5  0.023  0.023    27
# ...       ...  ...     ...         ...    ...  ...    ...    ...   ...
# 183955  부산 서구  대신동  221281  2013123120  0.012  0.5  0.040  0.022    71
# 183956  부산 서구  대신동  221281  2013123121  0.011  0.6  0.036  0.024    84
# 183957  부산 서구  대신동  221281  2013123122  0.013  0.6  0.029  0.030    84
# 183958  부산 서구  대신동  221281  2013123123  0.013  0.6  0.028  0.027    78
# 183959  부산 서구  대신동  221281  2013123124  0.013  0.6  0.032  0.021    88
#
#                 주소
# 0        부산 중구 광복동
# 1        부산 중구 광복동
# 2        부산 중구 광복동
# 3        부산 중구 광복동
# ...

# %%
df13.to_csv('2013.csv',index=False)

# %%
a = pd.read_csv('./data/dust/2014/2014년 1분기.csv',encoding='cp949')
b = pd.read_csv('./data/dust/2014/2014년 2분기.csv',encoding='cp949')
c = pd.read_csv('./data/dust/2014/2014년 3분기.csv',encoding='cp949')
d = pd.read_csv('./data/dust/2014/2014년 4분기.csv',encoding='cp949')
a = a[a['지역'].str.contains('부산')]
b = b[b['지역'].str.contains('부산')]
c = c[c['지역'].str.contains('부산')]
d = d[d['지역'].str.contains('부산')]
df14 = pd.concat([a,b,c,d], ignore_index=True)
df14
# Out:
#              지역   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2   PM10  \
# 0        부산 강서구  221211  대저동  2014010101  0.016  0.4  0.026  0.020  111.0
# 1        부산 강서구  221211  대저동  2014010102  0.014  0.4  0.027  0.017  118.0
# 2        부산 강서구  221211  대저동  2014010103  0.014  0.4  0.030  0.012  117.0
# 3        부산 강서구  221211  대저동  2014010104  0.015  0.4  0.026  0.012  136.0
# 4        부산 강서구  221211  대저동  2014010105  0.015  0.4  0.023  0.013  157.0
# ...         ...     ...  ...         ...    ...  ...    ...    ...    ...
# 183955  부산 해운대구  221192   좌동  2014123120  0.004  0.4  0.026  0.013   25.0
# 183956  부산 해운대구  221192   좌동  2014123121  0.004  0.3  0.025  0.013   25.0
# 183957  부산 해운대구  221192   좌동  2014123122  0.004  0.3  0.025  0.013   20.0
# 183958  부산 해운대구  221192   좌동  2014123123  0.004  0.4  0.026  0.010   26.0
# 183959  부산 해운대구  221192   좌동  2014123124  0.004  0.4  0.030  0.005   25.0
#
#         PM25                 주소
# 0        NaN  부산 강서구 대저1동(낙동북로)
# ...

# %%
df14 = df14.drop('PM25',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-d8201b65272f> in <module>
# ----> 1 df14 = df14.drop('PM25',axis=1)
#       2 df14.to_csv('2014.csv')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df14.to_csv('2014.csv',index=False)

# %%
a = pd.read_csv('./data/dust/2015/2015년1분기.csv')
b = pd.read_csv('./data/dust/2015/2015년2분기.csv')
c = pd.read_csv('./data/dust/2015/2015년3분기.csv')
d = pd.read_csv('./data/dust/2015/2015년4분기.csv')
a = a[a['지역'].str.contains('부산')]
b = b[b['지역'].str.contains('부산')]
c = c[c['지역'].str.contains('부산')]
d = d[d['지역'].str.contains('부산')]
df15 = pd.concat([a,b,c,d], ignore_index=True)
df15
# Out:
#              지역   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0        부산 강서구  221211  대저동  2015010101  0.005  0.2  0.029  0.003  27.0
# 1        부산 강서구  221211  대저동  2015010102  0.005  0.2  0.027  0.004  25.0
# 2        부산 강서구  221211  대저동  2015010103  0.005  0.2  0.027  0.003  26.0
# 3        부산 강서구  221211  대저동  2015010104  0.005  0.2  0.026  0.003  28.0
# 4        부산 강서구  221211  대저동  2015010105  0.005  0.2  0.024  0.004  32.0
# ...         ...     ...  ...         ...    ...  ...    ...    ...   ...
# 183955  부산 해운대구  221192   좌동  2015123120  0.005  1.0  0.019  0.023  71.0
# 183956  부산 해운대구  221192   좌동  2015123121  0.005  1.0  0.022  0.020  69.0
# 183957  부산 해운대구  221192   좌동  2015123122  0.005  1.1  0.012  0.028  63.0
# 183958  부산 해운대구  221192   좌동  2015123123  0.005  1.1  0.006  0.032  62.0
# 183959  부산 해운대구  221192   좌동  2015123124  0.006  1.1  0.004  0.033  68.0
#
#         PM25               주소
# 0       16.0  부산 강서구 낙동북로 236
# ...

# %%
df15.to_csv('2015.csv',index=False)

# %%
a = pd.read_csv('./data/dust/2016/2016년 1분기.csv',encoding='cp949')
b = pd.read_csv('./data/dust/2016/2016년 2분기.csv',encoding='cp949')
c = pd.read_csv('./data/dust/2016/2016년 3분기.csv',encoding='cp949')
d = pd.read_csv('./data/dust/2016/2016년 4분기.csv',encoding='cp949')
a = a[a['지역'].str.contains('부산')]
b = b[b['지역'].str.contains('부산')]
c = c[c['지역'].str.contains('부산')]
d = d[d['지역'].str.contains('부산')]
df16 = pd.concat([a,b,c,d], ignore_index=True)
df16
# Out:
#              지역   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0        부산 강서구  221211  대저동  2016010101  0.011  0.6  0.006  0.027  69.0
# 1        부산 강서구  221211  대저동  2016010102  0.018  0.6  0.006  0.028  67.0
# 2        부산 강서구  221211  대저동  2016010103  0.015  0.6  0.005  0.027  70.0
# 3        부산 강서구  221211  대저동  2016010104  0.019  0.6  0.006  0.025  70.0
# 4        부산 강서구  221211  대저동  2016010105  0.014  0.6  0.007  0.022  66.0
# ...         ...     ...  ...         ...    ...  ...    ...    ...   ...
# 184459  부산 해운대구  221192   좌동  2016123120  0.004  0.5  0.009  0.034  35.0
# 184460  부산 해운대구  221192   좌동  2016123121  0.004  0.5  0.008  0.033  41.0
# 184461  부산 해운대구  221192   좌동  2016123122  0.004  0.5  0.006  0.036  40.0
# 184462  부산 해운대구  221192   좌동  2016123123  0.004  0.7  0.003  0.039  42.0
# 184463  부산 해운대구  221192   좌동  2016123124  0.004  0.5  0.004  0.039  53.0
#
#         PM25                 주소
# 0       64.0  부산 강서구 대저1동(낙동북로)
# ...

# %%
df16.to_csv('2016.csv',index=False)

# %%
a1 = pd.read_excel('./data/dust/2017/2017년 1월.xlsx')
a2 = pd.read_excel('./data/dust/2017/2017년 2월.xlsx')
a3 = pd.read_excel('./data/dust/2017/2017년 3월.xlsx')
a4 = pd.read_excel('./data/dust/2017/2017년 4월.xlsx')
a5 = pd.read_excel('./data/dust/2017/2017년 5월.xlsx')
a6 = pd.read_excel('./data/dust/2017/2017년 6월.xlsx')
a7 = pd.read_excel('./data/dust/2017/2017년 7월.xlsx')
a8 = pd.read_excel('./data/dust/2017/2017년 8월.xlsx')
a9 = pd.read_excel('./data/dust/2017/2017년 9월.xlsx')
a10 = pd.read_excel('./data/dust/2017/2017년 10월.xlsx')
a11 = pd.read_excel('./data/dust/2017/2017년 11월.xlsx')
a12 = pd.read_excel('./data/dust/2017/2017년 12월.xlsx')

a1 = a1[a1['지역'].str.contains('부산')]
a2 = a2[a2['지역'].str.contains('부산')]
a3 = a3[a3['지역'].str.contains('부산')]
a4 = a4[a4['지역'].str.contains('부산')]
a5 = a5[a5['지역'].str.contains('부산')]
a6 = a6[a6['지역'].str.contains('부산')]
a7 = a7[a7['지역'].str.contains('부산')]
a8 = a8[a8['지역'].str.contains('부산')]
a9 = a9[a9['지역'].str.contains('부산')]
a10 = a10[a10['지역'].str.contains('부산')]
a11 = a11[a11['지역'].str.contains('부산')]
a12 = a12[a12['지역'].str.contains('부산')]

df17 = pd.concat([a1,a2,a3,a4,a5,a6,a7,a8,a9,a10,a11,a12], ignore_index=True)
df17
# Out:
#            지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0       부산 중구  도시대기  221112  광복동  2017010101  0.004  0.6  0.015  0.028  47.0
# 1       부산 중구  도시대기  221112  광복동  2017010102  0.004  0.5  0.026  0.016  45.0
# 2       부산 중구  도시대기  221112  광복동  2017010103  0.004  0.5  0.031  0.013  35.0
# 3       부산 중구  도시대기  221112  광복동  2017010104  0.004  0.5  0.027  0.018  39.0
# 4       부산 중구  도시대기  221112  광복동  2017010105  0.004  0.5  0.032  0.016  40.0
# ...       ...   ...     ...  ...         ...    ...  ...    ...    ...   ...
# 183955  부산 서구  도시대기  221281  대신동  2017123120  0.003  0.5  0.014  0.031  88.0
# 183956  부산 서구  도시대기  221281  대신동  2017123121  0.003  0.4  0.025  0.017  86.0
# 183957  부산 서구  도시대기  221281  대신동  2017123122  0.004  0.5  0.010  0.032  82.0
# 183958  부산 서구  도시대기  221281  대신동  2017123123  0.005  0.5  0.012  0.030  80.0
# 183959  부산 서구  도시대기  221281  대신동  2017123124  0.005  0.5  0.018  0.022  87.0
#
#         PM25                 주소
# ...

# %%
df17.to_csv('2017.csv',index=False,encoding='utf-8-sig')

# %%
a = pd.read_excel('./data/dust/2018/2018년 1분기.xlsx')
b = pd.read_excel('./data/dust/2018/2018년 2분기.xlsx')
c = pd.read_excel('./data/dust/2018/2018년 3분기.xlsx')
d = pd.read_excel('./data/dust/2018/2018년 4분기.xlsx')
a = a[a['지역'].str.contains('부산')]
b = b[b['지역'].str.contains('부산')]
c = c[c['지역'].str.contains('부산')]
d = d[d['지역'].str.contains('부산')]
df18 = pd.concat([a,b,c,d], ignore_index=True)
df18
# Out:
#             지역   측정소코드  측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0        부산 중구  221112   광복동  2018010101  0.003  0.4  0.032  0.014  71.0
# 1        부산 중구  221112   광복동  2018010102  0.003  0.4  0.032  0.013  53.0
# 2        부산 중구  221112   광복동  2018010103  0.003  0.4  0.033  0.011  52.0
# 3        부산 중구  221112   광복동  2018010104  0.004  0.4  0.034  0.010  43.0
# 4        부산 중구  221112   광복동  2018010105  0.004  0.4  0.034  0.009  53.0
# ...        ...     ...   ...         ...    ...  ...    ...    ...   ...
# 192427  부산 강서구  221902  부산신항  2018123120  0.004  0.5  0.017  0.058  39.0
# 192428  부산 강서구  221902  부산신항  2018123121  0.004  0.5  0.014  0.053  48.0
# 192429  부산 강서구  221902  부산신항  2018123122  0.004  0.4  0.011  0.044  42.0
# 192430  부산 강서구  221902  부산신항  2018123123  0.003  0.4  0.009  0.038  30.0
# 192431  부산 강서구  221902  부산신항  2018123124  0.004  0.4  0.013  0.031  27.0
#
#         PM25                 주소      망
# 0       20.0  부산 중구 광복로 55번길 10    NaN
# ...

# %%
df18.to_csv('2018.csv',index=False)

# %%
a1 = pd.read_excel('./data/dust/2019/2019년 1월.xlsx')
a2 = pd.read_excel('./data/dust/2019/2019년 2월.xlsx')
a3 = pd.read_excel('./data/dust/2019/2019년 3월.xlsx')
a4 = pd.read_excel('./data/dust/2019/2019년 4월.xlsx')
a5 = pd.read_excel('./data/dust/2019/2019년 5월.xlsx')
a6 = pd.read_excel('./data/dust/2019/2019년 6월.xlsx')
a7 = pd.read_excel('./data/dust/2019/2019년 7월.xlsx')
a8 = pd.read_excel('./data/dust/2019/2019년 8월.xlsx')
a9 = pd.read_excel('./data/dust/2019/2019년 9월.xlsx')
a10 = pd.read_excel('./data/dust/2019/2019년 10월.xlsx')
a11 = pd.read_excel('./data/dust/2019/2019년 11월.xlsx')
a12 = pd.read_excel('./data/dust/2019/2019년 12월.xlsx')

a1 = a1[a1['지역'].str.contains('부산')]
a2 = a2[a2['지역'].str.contains('부산')]
a3 = a3[a3['지역'].str.contains('부산')]
a4 = a4[a4['지역'].str.contains('부산')]
a5 = a5[a5['지역'].str.contains('부산')]
a6 = a6[a6['지역'].str.contains('부산')]
a7 = a7[a7['지역'].str.contains('부산')]
a8 = a8[a8['지역'].str.contains('부산')]
a9 = a9[a9['지역'].str.contains('부산')]
a10 = a10[a10['지역'].str.contains('부산')]
a11 = a11[a11['지역'].str.contains('부산')]
a12 = a12[a12['지역'].str.contains('부산')]

df19 = pd.concat([a1,a2,a3,a4,a5,a6,a7,a8,a9,a10,a11,a12], ignore_index=True)
df19
# Out:
#            지역   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  PM25  \
# 0       부산 중구  221112  광복동  2018010101  0.003  0.4  0.032  0.014  71.0  20.0
# 1       부산 중구  221112  광복동  2018010102  0.003  0.4  0.032  0.013  53.0  20.0
# 2       부산 중구  221112  광복동  2018010103  0.003  0.4  0.033  0.011  52.0  23.0
# 3       부산 중구  221112  광복동  2018010104  0.004  0.4  0.034  0.010  43.0  14.0
# 4       부산 중구  221112  광복동  2018010105  0.004  0.4  0.034  0.009  53.0  14.0
# ...       ...     ...  ...         ...    ...  ...    ...    ...   ...   ...
# 544315  부산 서구  221281  대신동  2018033120  0.005  0.5  0.039  0.034  51.0  28.0
# 544316  부산 서구  221281  대신동  2018033121  0.007  0.5  0.039  0.031  56.0  22.0
# 544317  부산 서구  221281  대신동  2018033122  0.004  0.5  0.081  0.013  52.0  28.0
# 544318  부산 서구  221281  대신동  2018033123  0.003  0.5  0.085  0.008  53.0  32.0
# 544319  부산 서구  221281  대신동  2018033124  0.005  0.5  0.079  0.011  55.0  22.0
#
#                        주소
# ...

# %%
df19.to_csv('2019.csv',index=False)

# %%
a1 = pd.read_excel('./data/dust/2020/2020년 1월.xlsx')
a2 = pd.read_excel('./data/dust/2020/2020년 2월.xlsx')
a3 = pd.read_excel('./data/dust/2020/2020년 3월.xlsx')
a4 = pd.read_excel('./data/dust/2020/2020년 4월.xlsx')
a5 = pd.read_excel('./data/dust/2020/2020년 5월.xlsx')
a6 = pd.read_excel('./data/dust/2020/2020년 6월.xlsx')
a7 = pd.read_excel('./data/dust/2020/2020년 7월.xlsx')
a8 = pd.read_excel('./data/dust/2020/2020년 8월.xlsx')
a9 = pd.read_excel('./data/dust/2020/2020년 9월.xlsx')
a10 = pd.read_excel('./data/dust/2020/2020년 10월.xlsx')
a11 = pd.read_excel('./data/dust/2020/2020년 11월.xlsx')
a12 = pd.read_excel('./data/dust/2020/2020년 12월.xlsx')

a1 = a1[a1['지역'].str.contains('부산')]
a2 = a2[a2['지역'].str.contains('부산')]
a3 = a3[a3['지역'].str.contains('부산')]
a4 = a4[a4['지역'].str.contains('부산')]
a5 = a5[a5['지역'].str.contains('부산')]
a6 = a6[a6['지역'].str.contains('부산')]
a7 = a7[a7['지역'].str.contains('부산')]
a8 = a8[a8['지역'].str.contains('부산')]
a9 = a9[a9['지역'].str.contains('부산')]
a10 = a10[a10['지역'].str.contains('부산')]
a11 = a11[a11['지역'].str.contains('부산')]
a12 = a12[a12['지역'].str.contains('부산')]

df20 = pd.concat([a1,a2,a3,a4,a5,a6,a7,a8,a9,a10,a11,a12], ignore_index=True)
df20

# %%
df20.to_csv('2020.csv',index=False)

# %%
df9= pd.read_csv('2011.csv')
df10= pd.read_csv('2012.csv')
df11= pd.read_csv('2013.csv')
df12= pd.read_csv('2014.csv')
df13= pd.read_csv('2015.csv')
df14= pd.read_csv('2016.csv')
df15= pd.read_csv('2017.csv')
df16= pd.read_csv('2018.csv')
df17= pd.read_csv('2019.csv')
df18= pd.read_csv('2020.csv')
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df9 = df9.sort_values(['측정일시','지역'])
df10 = df10.sort_values(['측정일시','지역'])
df11= df11.sort_values(['측정일시','지역'])
df12 = df12.sort_values(['측정일시','지역'])
df13 = df13.sort_values(['측정일시','지역'])
df14 = df14.sort_values(['측정일시','지역'])
df15 = df15.sort_values(['측정일시','지역'])
df16 = df16.sort_values(['측정일시','지역'])
df17 = df17.sort_values(['측정일시','지역'])
df18 = df18.sort_values(['측정일시','지역'])

# %%
df9 = df9.drop(['Unnamed: 0'],axis=1)
df10 = df10.drop(['Unnamed: 0'],axis=1)
df11= df11.drop(['Unnamed: 0'],axis=1)
df12 = df12.drop(['Unnamed: 0'],axis=1)
df13 = df13.drop(['Unnamed: 0'],axis=1)
df14 = df14.drop(['Unnamed: 0'],axis=1)
df15 = df15.drop(['Unnamed: 0'],axis=1)
df16 = df16.drop(['Unnamed: 0'],axis=1)
df17 = df17.drop(['Unnamed: 0'],axis=1)
df18 = df18.drop(['Unnamed: 0'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-b4fd56f931ea> in <module>
# ----> 1 df9 = df9.drop(['Unnamed: 0'],axis=1)
#       2 df10 = df10.drop(['Unnamed: 0'],axis=1)
#       3 df11= df11.drop(['Unnamed: 0'],axis=1)
#       4 df12 = df12.drop(['Unnamed: 0'],axis=1)
#       5 df13 = df13.drop(['Unnamed: 0'],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
df9.to_csv('2011년_3.csv',index=False,encoding='cp949')
df10.to_csv('2012년_3.csv',index=False,encoding='cp949')
df11.to_csv('2013년_3.csv',index=False,encoding='cp949')
df12.to_csv('2014년_3.csv',index=False,encoding='cp949')
df13.to_csv('2015년_3.csv',index=False,encoding='cp949')
df14.to_csv('2016년_3.csv',index=False,encoding='cp949')
df15.to_csv('2017년_3.csv',index=False,encoding='cp949')
df16.to_csv('2018년_3.csv',index=False,encoding='cp949')
df17.to_csv('2019년_3.csv',index=False,encoding='cp949')
df18.to_csv('2020년_3.csv',index=False,encoding='cp949')

# %%
df17
# Out:
#              지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  \
# 8928     부산 강서구  도시대기  221211  대저동  2017010101  0.018  0.5  0.004  0.028
# 9672     부산 강서구  도시대기  221212  녹산동  2017010101  0.004  0.3  0.015  0.022
# 6696     부산 금정구  도시대기  221191  청룡동  2017010101    NaN  NaN  0.007  0.033
# 13392    부산 금정구  도시대기  221251  부곡동  2017010101  0.002  0.7  0.005  0.043
# 11160    부산 기장군  도시대기  221231  기장읍  2017010101  0.004  0.4  0.033  0.011
# ...         ...   ...     ...  ...         ...    ...  ...    ...    ...
# 183215   부산 수영구  도시대기  221271  광안동  2017123124    NaN  NaN  0.028  0.015
# 179495   부산 연제구  도시대기  221221  연산동  2017123124    NaN  NaN  0.028  0.011
# 170567   부산 영도구  도시대기  221141  태종대  2017123124  0.004  0.2  0.029  0.013
# 169079    부산 중구  도시대기  221112  광복동  2017123124  0.004  0.4  0.027  0.019
# 176519  부산 해운대구  도시대기  221192   좌동  2017123124  0.004  0.4  0.027  0.014
#
#         PM10  PM25                        주소
# 8928    66.0  36.0        부산광역시 강서구 체육공원로 43
# ...

# %%
df20['측정일시'][1]%100
# Out:
# 2

# %%
for i in range(0,len(df9)):
    if df9['측정일시'][i]%100 == 0:
        df9['측정일시'][i] = df9['측정일시'][i]-76

# %%
len(df20)%100
# Out:
# 20

# %%
df9.head(40)
# Out:
#             지역 측정소명   측정소코드        측정일시      SO2     CO     O3    NO2  PM10  \
# 25910   부산 강서구  대저동  221211  2011010025    0.003    0.3  0.025  0.006    26
# 28070   부산 강서구  녹산동  221212  2011010025    0.004    0.3  0.024  0.008    28
# 19430   부산 금정구  청룡동  221191  2011010025 -999.000 -999.0  0.027  0.008    26
# 36709   부산 금정구  부곡동  221251  2011010025    0.005    0.7  0.030  0.011    26
# 32389   부산 기장군  기장읍  221231  2011010025    0.004    0.4  0.031  0.005    22
# 34549   부산 기장군  용수리  221233  2011010025    0.004    0.3  0.033  0.005    21
# 12954    부산 남구  대연동  221172  2011010025    0.004    0.4  0.027  0.010    28
# 2160     부산 동구  초량동  221131  2011010025    0.004    0.4  0.027  0.009    35
# 8640    부산 동래구  온천동  221162  2011010025    0.005    0.5  0.024  0.018    39
# 10794   부산 동래구  명장동  221163  2011010025 -999.000 -999.0  0.028  0.008    27
# 6480   부산 부산진구  전포동  221152  2011010025    0.003    0.5  0.031  0.007    26
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('기상자료.csv').drop(['True','False'],axis=1)

# %%
m= df['전운량(10분위)'].mean()

# %%
df['전운량(10분위)'].fillna(m,inplace = True)

# %%
df1 = pd.read_csv('2001년_3.csv',encoding='cp949')
df2 = pd.read_csv('2002년_3.csv',encoding='cp949')
df3 = pd.read_csv('2003년_3.csv',encoding='cp949')
df4 = pd.read_csv('2004년_3.csv',encoding='cp949')
df5 = pd.read_csv('2005년_3.csv',encoding='cp949')
df6 = pd.read_csv('2006년_3.csv',encoding='cp949')
df7 = pd.read_csv('2007년_3.csv',encoding='cp949')
df8 = pd.read_csv('2008년_3.csv',encoding='cp949')
df9 = pd.read_csv('2009년_3.csv',encoding='cp949')
df10 = pd.read_csv('2010년_3.csv',encoding='cp949')
df11 = pd.read_csv('2011년_3.csv',encoding='cp949')
df12 = pd.read_csv('2012년_3.csv',encoding='cp949')
df13 = pd.read_csv('2013년_3.csv',encoding='cp949')
df14 = pd.read_csv('2014년_3.csv',encoding='cp949')
df15 = pd.read_csv('2015년_3.csv',encoding='cp949')
df16 = pd.read_csv('2016년_3.csv',encoding='cp949')
df17 = pd.read_csv('2017년_3.csv',encoding='cp949')
df18 = pd.read_csv('2018년_3.csv',encoding='cp949')
df19 = pd.read_csv('2019년_3.csv',encoding='cp949')
df20 = pd.read_csv('2020년_3.csv',encoding='cp949')
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df1['PM10'] = df1['PM10'].replace(-999,np.NaN)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96360 entries, 0 to 96359
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      96360 non-null  object
#  1   측정소명    96360 non-null  object
#  2   측정소코드   96360 non-null  int64
#  3   측정일시    96360 non-null  int64
#  4   SO2     96360 non-null  float64
#  5   CO      96360 non-null  float64
#  6   O3      96360 non-null  float64
#  7   NO2     96360 non-null  float64
#  8   PM10    88167 non-null  float64
#  9   주소      96360 non-null  object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 7.4+ MB

# %%
df1['PM10'].mean()
# Out:
# 60.71248879966427

# %%
df1 = df1.replace(-999,np.NaN)
df2 = df2.replace(-999,np.NaN)
df3 = df3.replace(-999,np.NaN)
df4 = df4.replace(-999,np.NaN)
df5 = df5.replace(-999,np.NaN)
df6 = df6.replace(-999,np.NaN)
df7 = df7.replace(-999,np.NaN)
df8 = df8.replace(-999,np.NaN)
df9 = df9.replace(-999,np.NaN)
df10 = df10.replace(-999,np.NaN)
df11 = df11.replace(-999,np.NaN)
df12 = df12.replace(-999,np.NaN)
df13 = df13.replace(-999,np.NaN)
df14 = df14.replace(-999,np.NaN)
df15 = df15.replace(-999,np.NaN)
df16 = df16.replace(-999,np.NaN)
df17 = df17.replace(-999,np.NaN)
df18 = df18.replace(-999,np.NaN)
df19 = df19.replace(-999,np.NaN)
df20 = df20.replace(-999,np.NaN)

# %%
df6.head(50)
# Out:
#          지역 측정소명   측정소코드        측정일시    SO2   CO     O3    NO2  PM10  \
# 0    부산 강서구  대저동  221211  2006010101  0.006  0.7  0.005  0.026  41.0
# 1    부산 강서구  녹산동  221212  2006010101  0.002  0.3  0.033  0.007  26.0
# 2    부산 금정구  부곡동  221251  2006010101  0.003  0.9  0.007  0.031  29.0
# 3    부산 금정구  청룡동  221191  2006010101  0.005  0.5  0.020  0.038  25.0
# 4    부산 기장군  용수리  221233  2006010101  0.001  0.3  0.020  0.007  24.0
# 5    부산 기장군  기장읍  221231  2006010101  0.008  0.6  0.022  0.017  17.0
# 6     부산 남구  대연동  221172  2006010101  0.006  0.3  0.028  0.017  28.0
# 7     부산 동구  초량동  221131  2006010101  0.006  1.0  0.010  0.052  38.0
# 8    부산 동래구  명장동  221163  2006010101  0.002  0.5  0.014  0.025  30.0
# 9    부산 동래구  온천동  221162  2006010101  0.005  1.7  0.008  0.049  35.0
# 10  부산 부산진구  전포동  221152  2006010101  0.004  0.7  0.004  0.036  21.0
# 11    부산 북구  덕천동  221182  2006010101  0.001  0.3  0.011  0.020   NaN
# 12   부산 사상구  학장동  221181  2006010101  0.004  0.4  0.004  0.036  41.0
# ...

# %%
df1.to_csv('2001년.csv',index=False,encoding='utf-8-sig')
df2.to_csv('2002년.csv',index=False,encoding='utf-8-sig')
df3.to_csv('2003년.csv',index=False,encoding='utf-8-sig')
df4.to_csv('2004년.csv',index=False,encoding='utf-8-sig')
df5.to_csv('2005년.csv',index=False,encoding='utf-8-sig')
df6.to_csv('2006년.csv',index=False,encoding='utf-8-sig')
df7.to_csv('2007년.csv',index=False,encoding='utf-8-sig')
df8.to_csv('2008년.csv',index=False,encoding='utf-8-sig')
df9.to_csv('2009년.csv',index=False,encoding='utf-8-sig')
df10.to_csv('2010년.csv',index=False,encoding='utf-8-sig')
df11.to_csv('2011년.csv',index=False,encoding='utf-8-sig')
df12.to_csv('2012년.csv',index=False,encoding='utf-8-sig')
df13.to_csv('2013년.csv',index=False,encoding='utf-8-sig')
df14.to_csv('2014년.csv',index=False,encoding='utf-8-sig')
df15.to_csv('2015년.csv',index=False,encoding='utf-8-sig')
df16.to_csv('2016년.csv',index=False,encoding='utf-8-sig')
df17.to_csv('2017년.csv',index=False,encoding='utf-8-sig')
df18.to_csv('2018년.csv',index=False,encoding='utf-8-sig')
df19.to_csv('2019년.csv',index=False,encoding='utf-8-sig')
df20.to_csv('2020년.csv',index=False,encoding='utf-8-sig')

# %%
df19 = pd.read_csv('2019년.csv')
df20 = pd.read_csv('2020년.csv')

# %%
df17.to_csv('2017년.csv',index=False,encoding='utf-8-sig')
df19.to_csv('2019년.csv',index=False,encoding='utf-8-sig')
df20.to_csv('2020년.csv',index=False,encoding='utf-8-sig')

# %%
df17 = df17.sort_values(['측정일시','지역'])
df19 = df19.sort_values(['측정일시','지역'])
df20 = df20.sort_values(['측정일시','지역'])
df17 = df17.replace(-999,np.NaN)
df19 = df19.replace(-999,np.NaN)
df20 = df20.replace(-999,np.NaN)

# %%
def m(x):
    x['SO2'] = x['SO2'].replace(np.NaN,x['SO2'].mean())
    x['CO'] = x['CO'].replace(np.NaN,x['CO'].mean())
    x['O3'] = x['O3'].replace(np.NaN,x['O3'].mean())
    x['NO2'] = x['NO2'].replace(np.NaN,x['NO2'].mean())
    x['PM10'] = x['PM10'].replace(np.NaN,x['PM10'].mean())

# %%
def pm25(x):
    x['PM25'] = x['PM25'].replace(np.NaN,x['PM25'].mean())

# %%
m(df17)
m(df19)
m(df20)
pm25(df17)
pm25(df19)
pm25(df20)

# %%
m(df1)
m(df2)
m(df3)
m(df4)
m(df5)
m(df6)
m(df7)
m(df8)
m(df9)
m(df10)
m(df11)
m(df12)
m(df13)
m(df14)
m(df15)
m(df16)
m(df17)
m(df18)
m(df19)
m(df20)

# %%
pm25(df15)
pm25(df16)
pm25(df17)
pm25(df18)
pm25(df19)
pm25(df20)

# %%
for i in range(111048,len(df4)):
        df4['측정일시'][i] = df4['DATA_TINE'][i]
# Out:
# <ipython-input-159-283b84bbdbf5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['측정일시'][i] = df4['DATA_TINE'][i]

# %%
df4 = pd.read_csv('2004년.csv')

# %%
df4=df4.drop('DATA_TINE',axis=1)

# %%
df4['측정일시']=df4['측정일시'].astype(int)

# %%
df4['측정일시'] = df4['측정일시'].str.replace('-','')
df4['측정일시']=df4['측정일시'].str.replace(' ','')

# %%
df4['측정소명'].value_counts()
# Out:
# 장림동    8784
# 광복동    8784
# 연산동    8784
# 학장동    8784
# 광안동    8784
# 전포동    8784
# 대저동    8784
# 태종대    8784
# 기장읍    8784
# 대연동    8784
# 청룡동    8784
# 명장동    8784
# 초량동    8784
# 온천동    8784
# 덕천동    8784
# 부곡동    8784
# 녹산동    8040
# 용수리    1944
# Name: 측정소명, dtype: int64

# %%
dfw = pd.read_csv('기상자료.csv')

# %%
dfw
# Out:
#                 일시   지점 지점명  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0       2001010101  159  부산    -1.8      NaN      7.5     360.0   34.0
# 1       2001010102  159  부산    -2.0      NaN      8.1     360.0   35.0
# 2       2001010103  159  부산    -2.3      NaN      7.9     360.0   35.0
# 3       2001010104  159  부산    -2.7      NaN      6.0     360.0   37.0
# 4       2001010105  159  부산    -2.6      NaN      8.6     340.0   34.0
# ...            ...  ...  ..     ...      ...      ...       ...    ...
# 175314  2020123119  159  부산     0.6      NaN      6.2     270.0   41.0
# 175315  2020123120  159  부산     0.1      NaN      6.0     270.0   44.0
# 175316  2020123121  159  부산    -0.2      NaN      5.0     290.0   48.0
# 175317  2020123122  159  부산    -0.7      NaN      2.7     270.0   51.0
# 175318  2020123123  159  부산    -0.7      NaN      3.8     250.0   55.0
#
#         증기압(hPa)  이슬점온도(°C)  현지기압(hPa)  해면기압(hPa)  일조(hr)  일사(MJ/m2)  \
# ...

# %%
# df4['측정소명'].value_counts()
df20['측정소명'].value_counts()
# Out:
# 덕천동    25920
# 수정동    25920
# 용수리    25920
# 대연동    25920
# 광복동    25920
# 대신동    25920
# 학장동    25920
# 광안동    25920
# 전포동    25920
# 대저동    25920
# 청룡동    25920
# 온천동    25920
# 명장동    25920
# 부곡동    25920
# 연산동    25920
# 좌동     25920
# 장림동    25920
# 기장읍    25920
# 태종대    25920
# 초량동    25920
# 녹산동    25920
# Name: 측정소명, dtype: int64

# %%
# Out:
# 장림동    8784
# 광복동    8784
# 연산동    8784
# 학장동    8784
# 광안동    8784
# 전포동    8784
# 대저동    8784
# 태종대    8784
# 기장읍    8784
# 대연동    8784
# 청룡동    8784
# 명장동    8784
# 초량동    8784
# 온천동    8784
# 덕천동    8784
# 부곡동    8784
# 녹산동    8040
# 용수리    1944
# Name: 측정소명, dtype: int64

# %%
df3['측정소명'].value_counts()
# Out:
# 장림동    8760
# 광복동    8760
# 부곡동    8760
# 덕천동    8760
# 온천동    8760
# 초량동    8760
# 청룡동    8760
# 대연동    8760
# 태종대    8760
# 대저동    8760
# 전포동    8760
# 광안동    8760
# 학장동    8760
# 연산동    8760
# 기장읍    8760
# 명장동    5136
# Name: 측정소명, dtype: int64

# %%
df20['측정소명'].value_counts()
# Out:
# 덕천동    25920
# 수정동    25920
# 용수리    25920
# 대연동    25920
# 광복동    25920
# 대신동    25920
# 학장동    25920
# 광안동    25920
# 전포동    25920
# 대저동    25920
# 청룡동    25920
# 온천동    25920
# 명장동    25920
# 부곡동    25920
# 연산동    25920
# 좌동     25920
# 장림동    25920
# 기장읍    25920
# 태종대    25920
# 초량동    25920
# 녹산동    25920
# Name: 측정소명, dtype: int64

# %%
df6['측정소명'].value_counts()
# Out:
# 부곡동    8760
# 학장동    8760
# 녹산동    8760
# 좌동     8760
# 용수리    8760
# 대연동    8760
# 광복동    8760
# 장림동    8760
# 기장읍    8760
# 광안동    8760
# 덕천동    8760
# 전포동    8760
# 대저동    8760
# 태종대    8760
# 청룡동    8760
# 명장동    8760
# 초량동    8760
# 온천동    8760
# 연산동    8760
# Name: 측정소명, dtype: int64

# %%
df12['측정소명'].value_counts().count()
# Out:
# 20

# %%
dfw = dfw[105192:]

# %%
dfw.to_csv('기상자료(2013~).csv',index=False,encoding='utf-8-sig')

# %%
dfw.rename(columns={'일시':'측정일시'})
# Out:
#               측정일시   지점 지점명  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 105192  2013010101  159  부산    -2.4      NaN      1.8     340.0   54.0
# 105193  2013010102  159  부산    -2.5      NaN      1.9     340.0   53.0
# 105194  2013010103  159  부산    -2.0      NaN      1.7     320.0   52.0
# 105195  2013010104  159  부산    -2.3      NaN      2.1     320.0   54.0
# 105196  2013010105  159  부산    -2.5      NaN      0.4       0.0   55.0
# ...            ...  ...  ..     ...      ...      ...       ...    ...
# 175314  2020123119  159  부산     0.6      NaN      6.2     270.0   41.0
# 175315  2020123120  159  부산     0.1      NaN      6.0     270.0   44.0
# 175316  2020123121  159  부산    -0.2      NaN      5.0     290.0   48.0
# 175317  2020123122  159  부산    -0.7      NaN      2.7     270.0   51.0
# 175318  2020123123  159  부산    -0.7      NaN      3.8     250.0   55.0
#
#         증기압(hPa)  이슬점온도(°C)  현지기압(hPa)  해면기압(hPa)  일조(hr)  일사(MJ/m2)  \
# ...

# %%
dfw['강수량(mm)'] = dfw['강수량(mm)'].fillna(0)
dfw['일조(hr)'] = dfw['일조(hr)'].fillna(0)
dfw['일사(MJ/m2)'] = dfw['일사(MJ/m2)'].fillna(0)

# %%
dfw = dfw.drop('최저운고(100m )',axis=1)

# %%
dfw.head(48)
# Out:
#                 일시   지점 지점명  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 105192  2013010101  159  부산    -2.4      0.0      1.8     340.0   54.0
# 105193  2013010102  159  부산    -2.5      0.0      1.9     340.0   53.0
# 105194  2013010103  159  부산    -2.0      0.0      1.7     320.0   52.0
# 105195  2013010104  159  부산    -2.3      0.0      2.1     320.0   54.0
# 105196  2013010105  159  부산    -2.5      0.0      0.4       0.0   55.0
# 105197  2013010106  159  부산    -2.7      0.0      0.2       0.0   56.0
# 105198  2013010107  159  부산    -2.6      0.0      0.2       0.0   57.0
# 105199  2013010108  159  부산    -2.4      0.0      0.2       0.0   54.0
# 105200  2013010109  159  부산     1.1      0.0      0.2       0.0   45.0
# 105201  2013010110  159  부산     2.4      0.0      1.3     250.0   49.0
# 105202  2013010111  159  부산     5.4      0.0      4.5     230.0   52.0
# 105203  2013010112  159  부산     6.7      0.0      4.2     250.0   54.0
# ...

# %%
for i in range(len(dfw)):
    dfw['년월일'].iloc[i] = dfw['일시'].iloc[i][0:8]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '일시'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-362-ae1d9e852f2f> in <module>
#       1 for i in range(len(dfw)):
# ...

# %%
dfw['일시']=dfw['일시'].astype(str)

# %%
dfw['일시'].iloc[5][0:8]
# Out:
# '20130101'

# %%
dfw.columns
# Out:
# Index(['지점', '지점명', '기온(°C)', '강수량(mm)', '풍속(m/s)', '풍향(16방위)', '습도(%)',
#        '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)', '해면기압(hPa)', '일조(hr)',
#        '일사(MJ/m2)', '전운량(10분위)', '중하층운량(10분위)', '시정(10m)', '지면온도(°C)', '년월일'],
#       dtype='object')

# %%
x = ['기온(°C)', '강수량(mm)', '풍속(m/s)', '풍향(16방위)', '습도(%)',
       '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)', '해면기압(hPa)', '일조(hr)',
       '일사(MJ/m2)', '전운량(10분위)', '중하층운량(10분위)', '시정(10m)', '지면온도(°C)']

# %%
for i in x:
    dfw[i] = dfw[i].fillna(999)

# %%
dfw['전운량(10분위)'] = dfw['전운량(10분위)'].fillna(999)
dfw['중하층운량(10분위)'] = dfw['중하층운량(10분위)'].fillna(999)
dfw['시정(10m)'] = dfw['시정(10m)'].fillna(999)
dfw['풍속(m/s)'] = dfw['풍속(m/s)'].fillna(999)
dfw['풍향(16방위)'] = dfw['풍향(16방위)'].fillna(999)
aa['전운량(10분위)'] = aa['전운량(10분위)'].fillna(999)
aa['현지기압(hPa)'] = aa['현지기압(hPa)'].fillna(999)

# %%
for i in x:
    a(i)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
aa = dfw.groupby('년월일').mean()

# %%
aa
# Out:
#            지점    기온(°C)  강수량(mm)   풍속(m/s)    풍향(16방위)      습도(%)  증기압(hPa)  \
# 년월일
# 20130101  159  2.150000    0.000  3.066667  217.083333  49.500000  3.591667
# 20130102  159  0.537500    0.000  3.737500  307.083333  41.583333  2.758333
# 20130103  159 -5.175000    0.000  3.887500  252.083333  26.833333  1.100000
# 20130104  159 -2.804167    0.000  3.704167  310.000000  25.166667  1.245833
# 20130105  159 -0.691667    0.000  3.466667  300.000000  24.333333  1.420833
# ...       ...       ...      ...       ...         ...        ...       ...
# 20201227  159  7.029167    0.100  1.570833  144.166667  58.333333  5.741667
# 20201228  159  8.516667    0.000  1.754167  184.166667  66.333333  7.179167
# 20201229  159  8.641667    0.275  2.470833  206.250000  69.208333  7.608333
# 20201230  159 -2.787500    0.050  5.341667  267.500000  47.708333  2.554167
# 20201231  159 -3.304348    0.000  4.256522  250.000000  39.739130  1.973913
#
# ...

# %%
def a(x):
    for i in range(len(dfw)):
        if dfw[x].iloc[i] == 999.0:
            if aa[x].loc[dfw['년월일'].iloc[i]]==999:
                dfw[x].iloc[i] = aa[x].loc[dfw['년월일'].iloc[i-1]]
            else : dfw[x].iloc[i] = aa[x].loc[dfw['년월일'].iloc[i]]

# %%
def b(x):
    for i in range(len(dfw)):
        if dfw[x].iloc[i] == 999.0:
            if aa[x].loc[dfw['년월일'].iloc[i]]==999:
                dfw[x].iloc[i] = aa[x].loc[dfw['년월일'].iloc[i-1]]
            else : dfw[x].iloc[i] = aa[x].loc[dfw['년월일'].iloc[i]]

# %%
a('현지기압(hPa)')

# %%
for i in range(len(dfw)):
    if dfw['전운량(10분위)'].iloc[i].isnull() == True:
        print(dfw.iloc[i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-328-4fdcb97e1fc9> in <module>
#       1 for i in range(len(dfw)):
# ----> 2     if dfw['전운량(10분위)'].iloc[i].isnull() == True:
#       3         print(dfw.iloc[i])
#
# AttributeError: 'numpy.float64' object has no attribute 'isnull'

# %%
dfw=dfw.set_index('일시')

# %%
dfw.isnull().sum()
# Out:
# 지점             0
# 지점명            0
# 기온(°C)         0
# 강수량(mm)        0
# 풍속(m/s)        0
# 풍향(16방위)       0
# 습도(%)          0
# 증기압(hPa)       0
# 이슬점온도(°C)      0
# 현지기압(hPa)      0
# 해면기압(hPa)      0
# 일조(hr)         0
# 일사(MJ/m2)      0
# 전운량(10분위)      0
# 중하층운량(10분위)    0
# 시정(10m)        0
# 지면온도(°C)       0
# 년월일            0
# dtype: int64

# %%
aa.isnull().sum()
# Out:
# 지점             0
# 기온(°C)         0
# 강수량(mm)        0
# 풍속(m/s)        0
# 풍향(16방위)       0
# 습도(%)          0
# 증기압(hPa)       0
# 이슬점온도(°C)      0
# 현지기압(hPa)      0
# 해면기압(hPa)      0
# 일조(hr)         0
# 일사(MJ/m2)      0
# 전운량(10분위)      0
# 중하층운량(10분위)    0
# 시정(10m)        0
# 지면온도(°C)       0
# dtype: int64

# %%
a('풍속(m/s)')

# %%
dfw
# Out:
#              지점 지점명  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  증기압(hPa)  \
# 일시
# 2013010101  159  부산    -2.4      0.0      1.8     340.0   54.0       2.8
# 2013010102  159  부산    -2.5      0.0      1.9     340.0   53.0       2.7
# 2013010103  159  부산    -2.0      0.0      1.7     320.0   52.0       2.8
# 2013010104  159  부산    -2.3      0.0      2.1     320.0   54.0       2.8
# 2013010105  159  부산    -2.5      0.0      0.4       0.0   55.0       2.8
# ...         ...  ..     ...      ...      ...       ...    ...       ...
# 2020123119  159  부산     0.6      0.0      6.2     270.0   41.0       2.6
# 2020123120  159  부산     0.1      0.0      6.0     270.0   44.0       2.7
# 2020123121  159  부산    -0.2      0.0      5.0     290.0   48.0       2.9
# 2020123122  159  부산    -0.7      0.0      2.7     270.0   51.0       3.0
# 2020123123  159  부산    -0.7      0.0      3.8     250.0   55.0       3.2
#
#             이슬점온도(°C)  현지기압(hPa)  해면기압(hPa)  일조(hr)  일사(MJ/m2)  전운량(10분위)  \
# 일시
# ...

# %%
dfw.to_csv('기상자료_2.csv',index=False,encoding='utf-8-sig')

# %%
df1313=pd.read_csv('2013년.csv')

# %%
df1313.groupby(['측정일시','지역']).mean().drop('측정소코드',axis=1).to_csv('2013년_예시.csv',index=True,encoding='utf-8-sig')

# %%
dfw = pd.read_csv('기상자료_2.csv')

# %%
df = pd.read_csv('13_20.csv')

# %%
dfw1 = pd.read_csv('기상자료(2013~).csv')

# %%
dfw.insert(0,"측정일시",dfw1['일시'],True)

# %%
df = df.set_index('측정일시')

# %%
dfw = dfw.set_index('측정일시')

# %%
dfw = dfw.drop('년월일',axis=1)

# %%
dfw
# Out:
#              측정일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  증기압(hPa)  \
# 0      2013010101    -2.4      0.0      1.8     340.0   54.0       2.8
# 1      2013010102    -2.5      0.0      1.9     340.0   53.0       2.7
# 2      2013010103    -2.0      0.0      1.7     320.0   52.0       2.8
# 3      2013010104    -2.3      0.0      2.1     320.0   54.0       2.8
# 4      2013010105    -2.5      0.0      0.4       0.0   55.0       2.8
# ...           ...     ...      ...      ...       ...    ...       ...
# 70122  2020123119     0.6      0.0      6.2     270.0   41.0       2.6
# 70123  2020123120     0.1      0.0      6.0     270.0   44.0       2.7
# 70124  2020123121    -0.2      0.0      5.0     290.0   48.0       2.9
# 70125  2020123122    -0.7      0.0      2.7     270.0   51.0       3.0
# 70126  2020123123    -0.7      0.0      3.8     250.0   55.0       3.2
#
#        이슬점온도(°C)  현지기압(hPa)  해면기압(hPa)  일조(hr)  일사(MJ/m2)  전운량(10분위)  \
# ...

# %%
dfw.columns
# Out:
# Index(['기온(°C)', '강수량(mm)', '풍속(m/s)', '풍향(16방위)', '습도(%)', '증기압(hPa)',
#        '이슬점온도(°C)', '현지기압(hPa)', '해면기압(hPa)', '일조(hr)', '일사(MJ/m2)',
#        '전운량(10분위)', '중하층운량(10분위)', '시정(10m)', '지면온도(°C)'],
#       dtype='object')

# %%
x = ['기온(°C)', '강수량(mm)', '풍속(m/s)', '풍향(16방위)', '습도(%)', '증기압(hPa)',
       '이슬점온도(°C)', '현지기압(hPa)', '해면기압(hPa)', '일조(hr)', '일사(MJ/m2)',
       '전운량(10분위)', '중하층운량(10분위)', '시정(10m)', '지면온도(°C)']

# %%
for i in x:
    df[x] = np.nan

# %%
df
# Out:
#                측정일시       지역        CO       NO2       O3       PM10  \
# 0        2013010101   부산 강서구  0.500000  0.022000  0.01700  44.500000
# 1        2013010101   부산 금정구  0.422673  0.019000  0.02300  26.000000
# 2        2013010101   부산 기장군  0.650000  0.016000  0.02250  22.000000
# 3        2013010101    부산 남구  0.400000  0.025000  0.01800  25.000000
# 4        2013010101    부산 동구  0.550000  0.021000  0.01900  25.000000
# ...             ...      ...       ...       ...      ...        ...
# 1122043  2020123124   부산 수영구  0.380712  0.014000  0.01800  16.000000
# 1122044  2020123124   부산 연제구  0.300000  0.012000  0.02600  12.000000
# 1122045  2020123124   부산 영도구  0.300000  0.009500  0.02700  12.500000
# 1122046  2020123124    부산 중구  0.400000  0.009000  0.02600  20.000000
# 1122047  2020123124  부산 해운대구  0.340356  0.016316  0.02633  22.595056
#
#               PM25       SO2  기온(°C)  강수량(mm)  ...  증기압(hPa)  이슬점온도(°C)  \
# ...

# %%
for i in range(len(df)):
    for n in x:
        df[n][i]=dfw.loc[dfw['측정일시'] == df['측정일시'][i]][n][dfw.loc[dfw['측정일시'] == df['측정일시'][i]].index[0]]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-94f9be68dff5> in <module>
#       1 for i in range(len(df)):
#       2     for n in x:
# ----> 3         df[n][i]=dfw.loc[dfw['측정일시'] == df['측정일시'][i]][n][dfw.loc[dfw['측정일시'] == df['측정일시'][i]].index[0]]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
#      30
#      31     @unpack_zerodim_and_defer("__ne__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
# ...

# %%
dfw.loc[dfw['측정일시'] == df['측정일시'][1500]]['측정일시'][dfw.loc[dfw['측정일시'] == df['측정일시'][1500]].index[0]]
# Out:
# 2013010422

# %%
dfw.loc[dfw['측정일시'] == df['측정일시'][1]].index[0]
# Out:
# 0

# %%
dfa = pd.merge(df,dfw, how='outer',on='측정일시')

# %%
dfa = dfa.dropna()

# %%
dfa.isnull().sum()
# Out:
# 측정일시           0
# 지역             0
# CO             0
# NO2            0
# O3             0
# PM10           0
# SO2            0
# 기온(°C)         0
# 강수량(mm)        0
# 풍속(m/s)        0
# 풍향(16방위)       0
# 습도(%)          0
# 증기압(hPa)       0
# 이슬점온도(°C)      0
# 현지기압(hPa)      0
# 해면기압(hPa)      0
# 일조(hr)         0
# 일사(MJ/m2)      0
# 전운량(10분위)      0
# 중하층운량(10분위)    0
# 시정(10m)        0
# 지면온도(°C)       0
# dtype: int64

# %%
dfa.to_csv('데이터결합본_1.csv',index=False,encoding='utf-8-sig')

# %%
dfa.columns
# Out:
# Index(['측정일시', '지역', 'CO', 'NO2', 'O3', 'PM10', 'SO2', '기온(°C)', '강수량(mm)',
#        '풍속(m/s)', '풍향(16방위)', '습도(%)', '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)',
#        '해면기압(hPa)', '일조(hr)', '일사(MJ/m2)', '전운량(10분위)', '중하층운량(10분위)',
#        '시정(10m)', '지면온도(°C)'],
#       dtype='object')

# %%
dfa = dfa.drop('PM25',axis=1)

# %%
t=dfa[['CO', 'NO2', 'O3', 'PM10', 'SO2', '기온(°C)', '강수량(mm)',
       '풍속(m/s)', '풍향(16방위)', '습도(%)', '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)',
       '해면기압(hPa)', '일조(hr)', '일사(MJ/m2)', '전운량(10분위)', '중하층운량(10분위)',
       '시정(10m)', '지면온도(°C)']]

# %%
dfa.corr()
# Out:
#                  측정일시        CO       NO2        O3      PM10       SO2  \
# 측정일시         1.000000 -0.087456 -0.087565  0.058091 -0.229626 -0.316733
# CO          -0.087456  1.000000  0.478274 -0.174779  0.324985  0.203518
# NO2         -0.087565  0.478274  1.000000 -0.432774  0.365497  0.327731
# O3           0.058091 -0.174779 -0.432774  1.000000  0.085684 -0.021083
# PM10        -0.229626  0.324985  0.365497  0.085684  1.000000  0.348338
# SO2         -0.316733  0.203518  0.327731 -0.021083  0.348338  1.000000
# 기온(°C)       0.007049 -0.189620 -0.137006  0.231232 -0.030395  0.092946
# 강수량(mm)      0.017385 -0.038432 -0.038233 -0.018862 -0.087538 -0.049836
# 풍속(m/s)     -0.032838 -0.146692 -0.242214  0.272589  0.002936 -0.023917
# 풍향(16방위)    -0.002273  0.096253  0.104825 -0.048637  0.158738  0.016190
# 습도(%)        0.018426 -0.108803 -0.099993 -0.106464 -0.175952 -0.010420
# 증기압(hPa)     0.016021 -0.213589 -0.176667  0.068241 -0.139974  0.049464
# ...

# %%
plt.figure(figsize=(21,21))
sns.heatmap(data = t.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Reds')
plt.savefig('heatmap.png')

# %%
import matplotlib.pyplot as plt
from datetime import datetime
import keras

# %%
df=dfa

# %%
df.columns
# Out:
# Index(['측정일시', '지역', 'CO', 'NO2', 'O3', 'PM10', 'SO2', '기온(°C)', '강수량(mm)',
#        '풍속(m/s)', '풍향(16방위)', '습도(%)', '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)',
#        '해면기압(hPa)', '일조(hr)', '일사(MJ/m2)', '전운량(10분위)', '중하층운량(10분위)',
#        '시정(10m)', '지면온도(°C)'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
mlr = LinearRegression()
mlr.fit(x_train, y_train)

# %%
df = df.set_index('측정일시')

# %%
split = 2019010101

df_train = df[:split]
df_test = df[split:]

df_train_y = df_train.loc[:,'PM10']
df_train_x = df_train.drop('PM10', axis=1)

df_test_y = df_test.loc[:,'PM10']
df_test_x = df_test.drop('PM10', axis=1)

# LSTM 학습을 위해 3차원 배열로 X값을 변형
train_x = np.array(df_train_x).reshape(df_train_x.shape[0], df_train_x.shape[1], 1)
test_x = np.array(df_test_x).reshape(df_test_x.shape[0], df_test_x.shape[1], 1)

# %%
x = df[['지역','CO', 'NO2', 'O3', 'SO2', '기온(°C)', '강수량(mm)',
       '풍속(m/s)', '풍향(16방위)', '습도(%)', '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)',
       '해면기압(hPa)', '일조(hr)', '일사(MJ/m2)', '전운량(10분위)', '중하층운량(10분위)',
       '시정(10m)', '지면온도(°C)']]
y=df[['PM10']]
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8,test_size=0.2)

# %%
x_train
# Out:
#                  지역        CO       NO2       O3       SO2  기온(°C)  강수량(mm)  \
# 측정일시
# 2016122415   부산 연제구  0.500000  0.035000  0.01800  0.004000     9.2      0.0
# 2017022421   부산 강서구  0.350000  0.029000  0.01800  0.003000     3.2      0.0
# 2020092722    부산 서구  0.300000  0.009000  0.03300  0.003000    17.6      0.0
# 2020091713  부산 부산진구  0.440356  0.020816  0.02633  0.002816    22.5      0.3
# 2018011717   부산 수영구  0.366159  0.034000  0.01400  0.004986     7.9      0.0
# ...             ...       ...       ...      ...       ...     ...      ...
# 2016080319   부산 사상구  0.200000  0.028000  0.02600  0.003000    27.8      0.0
# 2020050122   부산 강서구  0.333333  0.009667  0.04300  0.004000    18.6      0.0
# 2014081216   부산 동래구  0.755514  0.026500  0.07200  0.006269    27.8      0.0
# 2018032512    부산 서구  0.500000  0.015000  0.05700  0.004000    17.8      0.0
# 2013121821   부산 사하구  0.300000  0.011000  0.01300  0.004000     6.5      0.0
#
# ...

# %%
x_train = x_train.values
x_test= x_test.values

y_train = y_train.values
y_test = y_test.values
print(x_train.shape)
print(x_train)
print(y_train.shape)
print(y_train)
# Out:
# (897625, 20)
# [['부산 서구' 0.4 0.014 ... 0.0 1900.0 3.5]
#  ['부산 동구' 0.55 0.0275 ... 6.842105263157895 557.8947368421053 6.9]
#  ['부산 사하구' 0.3 0.005 ... 5.0 2000.0 24.5]
#  ...
#  ['부산 연제구' 0.3 0.012 ... 0.1111111111111111 2000.0 2.5]
#  ['부산 서구' 0.2 0.011 ... 6.0 2000.0 27.8]
#  ['부산 금정구' 0.330516815980917 0.0125 ... 8.0 1573.0 42.8]]
# (897625, 1)
# [[47. ]
#  [54.5]
#  [14. ]
#  ...
#  [37. ]
#  [16. ]
#  [51.5]]

# %%
x_train_t = x_train.reshape(x_train.shape[0], 20, 1)
x_test_t = x_test.reshape(x_test.shape[0], 20, 1)

print("최종 DATA")
print(x_train_t.shape)
print(x_train_t)
print(y_train)
# Out:
# 최종 DATA
# (897625, 20, 1)
# [[['부산 서구']
#   [0.4]
#   [0.014]
#   ...
#   [0.0]
#   [1900.0]
#   [3.5]]
#
#  [['부산 동구']
#   [0.55]
#   [0.0275]
#   ...
#   [6.842105263157895]
#   [557.8947368421053]
#   [6.9]]
#
#  [['부산 사하구']
#   [0.3]
#   [0.005]
#   ...
#   [5.0]
#   [2000.0]
#   [24.5]]
#
#  ...
#
#  [['부산 연제구']
#   [0.3]
#   [0.012]
#   ...
#   [0.1111111111111111]
#   [2000.0]
#   [2.5]]
#
#  [['부산 서구']
#   [0.2]
#   [0.011]
#   ...
#   [6.0]
#   [2000.0]
#   [27.8]]
#
#  [['부산 금정구']
#   [0.330516815980917]
#   [0.0125]
#   ...
#   [8.0]
#   [1573.0]
#   [42.8]]]
# [[47. ]
#  [54.5]
#  [14. ]
#  ...
#  [37. ]
#  [16. ]
#  [51.5]]

# %%
import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import itertools
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dropout

# input shape에 전처리된 train_x의 형태를 넣는다
# 20%로 Drop-out 했다


model = keras.Sequential()
model.add(keras.layers.LSTM(20,input_shape=(x_train_t.shape[1], x_train_t.shape[2])))
model.add(keras.layers.Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()

# 10개의 batch로 100번 epoch 함
# history = model.fit(x_train, y_train, validation_split=0.1, batch_size=10, epochs=100)

# pd.DataFrame.from_dict(history.history).plot()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_5 (LSTM)               (None, 20)                1760
#
#  dense_4 (Dense)             (None, 1)                 21
#
# ...
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-81c313c0c932> in <module>
#      25 # pd.DataFrame.from_dict(history.history).plot()
#      26 early_stop = EarlyStopping(monitor='loss', patience=1, verbose=1)
# ---> 27 model.fit(x_train_t, y_train, epochs=100,batch_size=30, verbose=1, callbacks=[early_stop])
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
# ...

# %%
early_stop = EarlyStopping(monitor='loss', patience=1, verbose=1)
model.fit(x_train_t, y_train, epochs=100,batch_size=30, verbose=1, callbacks=[early_stop])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-36ad90ac734a> in <module>
#       1 early_stop = EarlyStopping(monitor='loss', patience=1, verbose=1)
# ----> 2 model.fit(x_train_t, y_train, epochs=100,batch_size=30, verbose=1, callbacks=[early_stop])
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     104       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105   ctx.ensure_initialized()
# ...

# %%
import statsmodels

# %%
# crim, rm, lstat을 통한 다중 선형회귀분석
x_data = df[['CO', 'NO2', 'O3', 'SO2', '기온(°C)', '강수량(mm)',
       '풍속(m/s)', '풍향(16방위)', '습도(%)', '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)',
       '해면기압(hPa)', '일조(hr)', '일사(MJ/m2)', '전운량(10분위)', '중하층운량(10분위)',
       '시정(10m)', '지면온도(°C)']] #변수 여러개
target = df[["PM10"]]

# for b0, 상수항 추가
x_data1 = sm.add_constant(x_data, has_constant = "add")

# OLS 검정
multi_model = sm.OLS(target, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   PM10   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                 3.813e+04
# Date:                Wed, 10 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:33:18   Log-Likelihood:            -4.9230e+06
# No. Observations:             1122032   AIC:                         9.846e+06
# Df Residuals:                 1122012   BIC:                         9.846e+06
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          67.0444      4.095     16.372      0.000      59.018      75.070
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(x_data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-21584959c659> in <module>
#       1 sns.pairplot(x_data)
# ----> 2 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
# ...
